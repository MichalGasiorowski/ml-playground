# %%
import os
import seaborn as sns
import numpy as np
import pandas as pd

import tensorflow as tf

# %%
# !pip install -q kaggle
#!pip install google.colab
# Out:
# ERROR: jupyterlab-git 0.10.1 has requirement nbdime<2.0.0,>=1.1.0, but you'll have nbdime 2.0.0 which is incompatible.
# ERROR: apache-beam 2.22.0 has requirement httplib2<0.18.0,>=0.8, but you'll have httplib2 0.18.1 which is incompatible.
# ERROR: apache-beam 2.22.0 has requirement mock<3.0.0,>=1.0.1, but you'll have mock 4.0.2 which is incompatible.
# Collecting google.colab
#   Downloading google-colab-1.0.0.tar.gz (72 kB)
#      |████████████████████████████████| 72 kB 1.4 MB/s eta 0:00:011
# Collecting google-auth~=1.4.0
#   Downloading google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.8 MB/s  eta 0:00:01
# Collecting ipykernel~=4.6.0
#   Downloading ipykernel-4.6.1-py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 14.5 MB/s eta 0:00:01
# Collecting ipython~=5.5.0
#   Downloading ipython-5.5.0-py3-none-any.whl (758 kB)
#      |████████████████████████████████| 758 kB 14.7 MB/s eta 0:00:01
# Collecting notebook~=5.2.0
#   Downloading notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 27.7 MB/s eta 0:00:01
# Collecting six~=1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting pandas~=0.24.0
#   Downloading pandas-0.24.2-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 48.1 MB/s eta 0:00:01
# Collecting portpicker~=1.2.0
#   Downloading portpicker-1.2.0.tar.gz (17 kB)
# Collecting requests~=2.21.0
#   Downloading requests-2.21.0-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.6 MB/s  eta 0:00:01
# Collecting tornado~=4.5.0
#   Downloading tornado-4.5.3.tar.gz (484 kB)
#      |████████████████████████████████| 484 kB 74.1 MB/s eta 0:00:01
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth~=1.4.0->google.colab) (0.2.8)
# Requirement already satisfied: cachetools>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth~=1.4.0->google.colab) (4.1.1)
# Requirement already satisfied: rsa>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth~=1.4.0->google.colab) (4.6)
# Requirement already satisfied: jupyter-client in /opt/conda/lib/python3.7/site-packages (from ipykernel~=4.6.0->google.colab) (6.1.5)
# Requirement already satisfied: traitlets>=4.1.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel~=4.6.0->google.colab) (4.3.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython~=5.5.0->google.colab) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.7/site-packages (from ipython~=5.5.0->google.colab) (49.1.0.post20200704)
# Requirement already satisfied: simplegeneric>0.8 in /opt/conda/lib/python3.7/site-packages (from ipython~=5.5.0->google.colab) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/conda/lib/python3.7/site-packages (from ipython~=5.5.0->google.colab) (4.8.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython~=5.5.0->google.colab) (0.7.5)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from ipython~=5.5.0->google.colab) (2.6.1)
# Collecting prompt-toolkit<2.0.0,>=1.0.4
#   Downloading prompt_toolkit-1.0.18-py3-none-any.whl (245 kB)
#      |████████████████████████████████| 245 kB 74.9 MB/s eta 0:00:01
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from notebook~=5.2.0->google.colab) (0.2.0)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.7/site-packages (from notebook~=5.2.0->google.colab) (5.6.1)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.7/site-packages (from notebook~=5.2.0->google.colab) (5.0.7)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from notebook~=5.2.0->google.colab) (2.11.2)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.7/site-packages (from notebook~=5.2.0->google.colab) (4.6.3)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /opt/conda/lib/python3.7/site-packages (from notebook~=5.2.0->google.colab) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/lib/python3.7/site-packages (from pandas~=0.24.0->google.colab) (2.8.1)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.7/site-packages (from pandas~=0.24.0->google.colab) (2020.1)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/lib/python3.7/site-packages (from pandas~=0.24.0->google.colab) (1.19.0)
# Collecting idna<2.9,>=2.5
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 8.0 MB/s  eta 0:00:01
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests~=2.21.0->google.colab) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests~=2.21.0->google.colab) (2020.6.20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests~=2.21.0->google.colab) (3.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth~=1.4.0->google.colab) (0.4.8)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.7/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (19.0.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython~=5.5.0->google.colab) (0.6.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython~=5.5.0->google.colab) (0.2.5)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.8.4)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.4.4)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.6.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (3.1.5)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat->notebook~=5.2.0->google.colab) (3.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->notebook~=5.2.0->google.colab) (1.1.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->notebook~=5.2.0->google.colab) (20.4)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->notebook~=5.2.0->google.colab) (0.5.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google.colab) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google.colab) (0.16.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google.colab) (1.7.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook~=5.2.0->google.colab) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google.colab) (3.1.0)
# Building wheels for collected packages: google.colab, portpicker, tornado
#   Building wheel for google.colab (setup.py) ... done
#   Created wheel for google.colab: filename=google_colab-1.0.0-py2.py3-none-any.whl size=102289 sha256=50745992ccd445ff7ea9e9433489750dfbd8eb1b0edd2e226f118a5c3ccb19ba
#   Stored in directory: /home/jupyter/.cache/pip/wheels/f6/3b/58/f34ea9045a7c69bd5634978bf25ac60277e90997d9e6e74192
#   Building wheel for portpicker (setup.py) ... done
#   Created wheel for portpicker: filename=portpicker-1.2.0-py3-none-any.whl size=13369 sha256=68c88b23ffe14ff19d48eb9f44f8c46de01a48c39a6c83e37d09fabad885b7cd
#   Stored in directory: /home/jupyter/.cache/pip/wheels/73/0c/f5/35977446e45e818e6b848be3d41e7f38298a5102f4dcda21c6
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-4.5.3-cp37-cp37m-linux_x86_64.whl size=434061 sha256=85415f12c0347b9d017812119fde9095e2176fc5df26762c69cb48e18376360a
#   Stored in directory: /home/jupyter/.cache/pip/wheels/a2/45/43/36ec7a893e16c1212a6b1505ded0a2d73cf8e863a0227c8e04
# Successfully built google.colab portpicker tornado
# ERROR: witwidget 1.7.0 has requirement oauth2client>=4.1.3, but you'll have oauth2client 3.0.0 which is incompatible.
# ERROR: visions 0.4.4 has requirement pandas>=0.25.3, but you'll have pandas 0.24.2 which is incompatible.
# ERROR: tfx 0.22.0 has requirement pyarrow<0.17,>=0.16, but you'll have pyarrow 0.17.1 which is incompatible.
# ERROR: tfx-bsl 0.22.1 has requirement pyarrow<0.17,>=0.16.0, but you'll have pyarrow 0.17.1 which is incompatible.
# ERROR: tensorflow 2.1.1 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.5.0 which is incompatible.
# ERROR: tensorflow-model-analysis 0.22.2 has requirement pyarrow<0.17,>=0.16, but you'll have pyarrow 0.17.1 which is incompatible.
# ERROR: tensorflow-model-analysis 0.22.2 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.5.0 which is incompatible.
# ERROR: tensorflow-io 0.11.0 has requirement tensorflow==2.1.0, but you'll have tensorflow 2.1.1 which is incompatible.
# ERROR: tensorflow-data-validation 0.22.2 has requirement joblib<0.15,>=0.12, but you'll have joblib 0.16.0 which is incompatible.
# ERROR: tensorflow-data-validation 0.22.2 has requirement pyarrow<0.17,>=0.16, but you'll have pyarrow 0.17.1 which is incompatible.
# ERROR: tensorboard 2.1.1 has requirement google-auth<2,>=1.6.3, but you'll have google-auth 1.4.2 which is incompatible.
# ERROR: spyder-kernels 1.9.1 has requirement ipykernel>=5.1.3; python_version > "2", but you'll have ipykernel 4.6.1 which is incompatible.
# ERROR: pandas-profiling 2.8.0 has requirement pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3, but you'll have pandas 0.24.2 which is incompatible.
# ERROR: pandas-profiling 2.8.0 has requirement requests>=2.23.0, but you'll have requests 2.21.0 which is incompatible.
# ERROR: jupyterlab-git 0.10.1 has requirement nbdime<2.0.0,>=1.1.0, but you'll have nbdime 2.0.0 which is incompatible.
# ERROR: jupyter-console 6.1.0 has requirement prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0, but you'll have prompt-toolkit 1.0.18 which is incompatible.
# ERROR: google-cloud-storage 1.29.0 has requirement google-auth<2.0dev,>=1.11.0, but you'll have google-auth 1.4.2 which is incompatible.
# ERROR: google-cloud-bigquery 1.25.0 has requirement google-auth<2.0dev,>=1.9.0, but you'll have google-auth 1.4.2 which is incompatible.
# ERROR: google-cloud-bigquery 1.25.0 has requirement six<2.0.0dev,>=1.13.0, but you'll have six 1.12.0 which is incompatible.
# ERROR: google-api-python-client 1.9.1 has requirement google-auth>=1.16.0, but you'll have google-auth 1.4.2 which is incompatible.
# ERROR: google-api-core 1.21.0 has requirement google-auth<2.0dev,>=1.18.0, but you'll have google-auth 1.4.2 which is incompatible.
# ERROR: distributed 2.20.0 has requirement tornado>=5; python_version < "3.8", but you'll have tornado 4.5.3 which is incompatible.
# ERROR: cookiecutter 1.7.2 has requirement requests>=2.23.0, but you'll have requests 2.21.0 which is incompatible.
# ERROR: bokeh 2.1.1 has requirement tornado>=5.1, but you'll have tornado 4.5.3 which is incompatible.
# ERROR: apache-beam 2.22.0 has requirement httplib2<0.18.0,>=0.8, but you'll have httplib2 0.18.1 which is incompatible.
# ERROR: apache-beam 2.22.0 has requirement mock<3.0.0,>=1.0.1, but you'll have mock 4.0.2 which is incompatible.
# Installing collected packages: six, google-auth, tornado, prompt-toolkit, ipython, ipykernel, notebook, pandas, portpicker, idna, requests, google.colab
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.18.0
#     Uninstalling google-auth-1.18.0:
#       Successfully uninstalled google-auth-1.18.0
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.4
#     Uninstalling tornado-6.0.4:
#       Successfully uninstalled tornado-6.0.4
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.5
#     Uninstalling prompt-toolkit-3.0.5:
#       Successfully uninstalled prompt-toolkit-3.0.5
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.16.1
#     Uninstalling ipython-7.16.1:
#       Successfully uninstalled ipython-7.16.1
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.3.1
#     Uninstalling ipykernel-5.3.1:
#       Successfully uninstalled ipykernel-5.3.1
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.0.3
#     Uninstalling notebook-6.0.3:
#       Successfully uninstalled notebook-6.0.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
# Successfully installed google-auth-1.17.2 google.colab idna-2.8 ipykernel-4.6.1 ipython-5.5.0 notebook-5.2.2 pandas-0.24.2 portpicker-1.2.0 prompt-toolkit-1.0.18 requests-2.21.0 six-1.12.0 tornado-4.5.3

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json

# !ls -l ~/.kaggle/kaggle.json
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory
# kaggle.json
# -rw------- 1 jupyter jupyter 73 Jul 20 16:39 /home/jupyter/.kaggle/kaggle.json

# %%
data_base_path = os.path.join(os.path.curdir, '../../../../data')
print(data_base_path)
# !ls $data_base_path
# Out:
# ./../../../../data
# ls: cannot access './../../../../data': No such file or directory

# %%
def load_data_from_kaggle(dataset="titanic", data_base_path=data_base_path):
    data_path = os.path.join(os.path.curdir, f"{data_base_path}/{dataset}")
    # !kaggle competitions download -c $dataset --path $data_path --force
    # !unzip -o $data_path/titanic.zip -d $data_path

# %%
load_data_from_kaggle(dataset="titanic")
# Out:
# Downloading titanic.zip to ././../../../../data/titanic
#   0%|                                               | 0.00/34.1k [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 34.1k/34.1k [00:00<00:00, 23.5MB/s]
# Archive:  ././../../../../data/titanic/titanic.zip
#   inflating: ././../../../../data/titanic/gender_submission.csv
#   inflating: ././../../../../data/titanic/test.csv
#   inflating: ././../../../../data/titanic/train.csv

# %%
def load_titanic_dateset(titanic_path='/content'):
    gender_submission_csv_path = os.path.join(titanic_path, "gender_submission.csv")
    train_csv_path = os.path.join(titanic_path, "train.csv")
    test_csv_path = os.path.join(titanic_path, "test.csv")
    return pd.read_csv(gender_submission_csv_path), pd.read_csv(train_csv_path), pd.read_csv(test_csv_path)

# %%
gender_sub_df, train_df, test_df = load_titanic_dateset(titanic_path=f'{data_base_path}/titanic')

# %%
train_df.head(1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343     def __contains__(self, typ):
#     344         """map in to lookup_by_type"""
# --> 345         try:
#     346             self.lookup_by_type(typ)
#     347         except KeyError:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732         Property returning a Styler object containing methods for
#     733         building a styled HTML representation fo the DataFrame.
# --> 734
#     735         See Also
#     736         --------
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     977                     # False specifically, so that the default is
#     978                     # to include a space if we get here.
# --> 979                     tpl = u'{v}'
#     980                 else:
#     981                     tpl = u' {v}'
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/formats/html.py in <module>
#       8 from textwrap import dedent
#       9
# ---> 10 from pandas.compat import OrderedDict, lzip, map, range, u, unichr, zip
#      11
#      12 from pandas.core.dtypes.generic import ABCMultiIndex
#
# ImportError: cannot import name 'OrderedDict' from 'pandas.compat' (/opt/conda/lib/python3.7/site-packages/pandas/compat/__init__.py)
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
# !pip freeze
# Out:
# absl-py==0.8.1
# adal @ file:///home/conda/feedstock_root/build_artifacts/adal_1591523462562/work
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-project==0.8.3
# ansiwrap==0.8.4
# apache-beam==2.22.0
# appdirs==1.4.3
# argh==0.26.2
# arrow @ file:///home/conda/feedstock_root/build_artifacts/arrow_1592592061553/work
# asn1crypto @ file:///home/conda/feedstock_root/build_artifacts/asn1crypto_1588618038116/work
# astor==0.8.1
# astroid @ file:///home/conda/feedstock_root/build_artifacts/astroid_1591645081755/work
# astropy==4.0.1.post1
# async-generator==1.10
# atomicwrites @ file:///home/conda/feedstock_root/build_artifacts/atomicwrites_1588182545583/work
# attrs==19.3.0
# autopep8==1.5.2
# avro-python3==1.9.2.1
# Babel==2.8.0
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.shutil-get-terminal-size==1.0.0
# bcolz==1.2.1
# beautifulsoup4 @ file:///home/conda/feedstock_root/build_artifacts/beautifulsoup4_1589761456552/work
# binaryornot==0.4.4
# bitarray @ file:///home/conda/feedstock_root/build_artifacts/bitarray_1594039665500/work
# bkcharts==0.2
# black==19.10b0
# bleach @ file:///home/conda/feedstock_root/build_artifacts/bleach_1588608214987/work
# blinker==1.4
# bokeh @ file:///home/conda/feedstock_root/build_artifacts/bokeh_1592869573618/work
# boto==2.49.0
# Bottleneck==1.3.2
# brotlipy==0.7.0
# cachetools @ file:///home/conda/feedstock_root/build_artifacts/cachetools_1593420445823/work
# certifi==2020.6.20
# cffi==1.14.0
# chardet==3.0.4
# click==7.1.2
# cloudpickle @ file:///home/conda/feedstock_root/build_artifacts/cloudpickle_1593623337153/work
# clyent==1.2.2
# colorama==0.4.3
# conda==4.8.3
# conda-package-handling==1.7.0
# confuse @ file:///home/conda/feedstock_root/build_artifacts/confuse_1593279073800/work
# contextlib2==0.6.0.post1
# cookiecutter==1.7.2
# crcmod==1.7
# cryptography==2.9.2
# cycler==0.10.0
# Cython @ file:///home/conda/feedstock_root/build_artifacts/cython_1591799499719/work
# cytoolz==0.10.1
# dask @ file:///home/conda/feedstock_root/build_artifacts/dask-core_1593753420471/work
# decorator==4.4.2
# defusedxml==0.6.0
# diff-match-patch==20181111
# dill==0.3.1.1
# distributed @ file:///home/conda/feedstock_root/build_artifacts/distributed_1593754191641/work
# docker @ file:///home/conda/feedstock_root/build_artifacts/docker-py_1593588220651/work
# docker-pycreds==0.4.0
# docopt==0.6.2
# docutils==0.16
# entrypoints==0.3
# et-xmlfile==1.0.1
# fastavro==0.23.5
# fastcache==1.1.0
# fasteners==0.15
# filelock @ file:///home/conda/feedstock_root/build_artifacts/filelock_1589994591731/work
# flake8==3.7.9
# Flask==1.1.2
# fsspec @ file:///home/conda/feedstock_root/build_artifacts/fsspec_1589989738418/work
# future==0.18.2
# gast==0.2.2
# gcsfs @ file:///home/conda/feedstock_root/build_artifacts/gcsfs_1588858323173/work
# gevent @ file:///home/conda/feedstock_root/build_artifacts/gevent_1592657467591/work
# gitdb @ file:///home/conda/feedstock_root/build_artifacts/gitdb_1588651542737/work
# GitPython @ file:///home/conda/feedstock_root/build_artifacts/gitpython_1590897464411/work
# glob2==0.7
# gmpy2==2.1.0b1
# google-api-core==1.21.0
# google-api-python-client @ file:///home/conda/feedstock_root/build_artifacts/google-api-python-client_1591125360815/work
# google-apitools==0.5.31
# google-auth @ file:///home/conda/feedstock_root/build_artifacts/google-auth_1592232565626/work
# google-auth-httplib2==0.0.3
# google-auth-oauthlib==0.4.1
# google-cloud-bigquery==1.25.0
# google-cloud-bigtable==1.2.1
# google-cloud-core==1.3.0
# google-cloud-dataproc==1.0.0
# google-cloud-datastore==1.12.0
# google-cloud-dlp==0.13.0
# google-cloud-firestore==1.7.0
# google-cloud-kms==1.4.0
# google-cloud-language==1.3.0
# google-cloud-logging==1.15.0
# google-cloud-pubsub==1.6.0
# google-cloud-scheduler==1.3.0
# google-cloud-spanner==1.17.1
# google-cloud-speech==1.3.2
# google-cloud-storage==1.29.0
# google-cloud-tasks==1.5.0
# google-cloud-translate==2.0.1
# google-cloud-videointelligence==1.15.0
# google-cloud-vision==1.0.0
# google-colab==1.0.0
# google-pasta==0.2.0
# google-resumable-media==0.5.1
# googleapis-common-protos==1.51.0
# greenlet @ file:///home/conda/feedstock_root/build_artifacts/greenlet_1591368821264/work
# grpc-google-iam-v1==0.12.3
# grpcio==1.30.0
# grpcio-gcp==0.2.2
# h5py @ file:///home/conda/feedstock_root/build_artifacts/h5py_1593217410729/work
# hdfs==2.5.8
# HeapDict==1.0.1
# html5lib @ file:///home/conda/feedstock_root/build_artifacts/html5lib_1592930327044/work
# htmlmin==0.1.12
# httplib2 @ file:///home/conda/feedstock_root/build_artifacts/httplib2_1590007784658/work
# hypothesis @ file:///home/conda/feedstock_root/build_artifacts/hypothesis_1593564453829/work
# idna==2.8
# imagecodecs @ file:///home/conda/feedstock_root/build_artifacts/imagecodecs_1593295475914/work
# ImageHash @ file:///home/conda/feedstock_root/build_artifacts/imagehash_1588182723834/work
# imageio @ file:///home/conda/feedstock_root/build_artifacts/imageio_1594044661732/work
# imagesize==1.2.0
# importlib-metadata @ file:///home/conda/feedstock_root/build_artifacts/importlib-metadata_1593211369179/work
# intervaltree==3.0.2
# ipykernel==4.6.1
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipython-sql @ file:///home/conda/feedstock_root/build_artifacts/ipython-sql_1588134460796/work
# ipywidgets==7.5.1
# isort==4.3.21
# itsdangerous==1.1.0
# jdcal==1.4.1
# jedi==0.15.2
# jeepney==0.4.3
# Jinja2==2.11.2
# jinja2-time==0.2.0
# joblib @ file:///home/conda/feedstock_root/build_artifacts/joblib_1593624380152/work
# json5 @ file:///home/conda/feedstock_root/build_artifacts/json5_1591810480056/work
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-aihub-deploy-extension @ file:///opt/conda/conda-bld/dlenv-base_1593468110918/work/packages/aihub/jupyter_aihub_deploy_extension
# jupyter-client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1593562235049/work
# jupyter-console==6.1.0
# jupyter-core==4.6.3
# jupyter-http-over-ws==0.0.8
# jupyterlab==1.2.16
# jupyterlab-git @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab-git_1591177886792/work
# jupyterlab-server @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_server_1593951277307/work
# kaggle==1.5.6
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# keras-tuner==1.0.1
# keyring @ file:///home/conda/feedstock_root/build_artifacts/keyring_1588433935863/work
# kiwisolver==1.2.0
# kubernetes @ file:///home/conda/feedstock_root/build_artifacts/python-kubernetes_1588618980778/work
# lazy-object-proxy==1.4.3
# libarchive-c==2.9
# lief==0.9.0
# llvmlite==0.33.0
# locket==0.2.0
# lxml @ file:///home/conda/feedstock_root/build_artifacts/lxml_1589927514031/work
# Markdown @ file:///home/conda/feedstock_root/build_artifacts/markdown_1589366472132/work
# MarkupSafe==1.1.1
# matplotlib @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-base_1592576108701/work
# mccabe==0.6.1
# missingno==0.4.2
# mistune==0.8.4
# mkl-fft==1.1.0
# mkl-random==1.1.0
# mkl-service==2.3.0
# ml-metadata==0.22.1
# mock @ file:///home/conda/feedstock_root/build_artifacts/mock_1588618847833/work
# monotonic==1.5
# more-itertools @ file:///home/conda/feedstock_root/build_artifacts/more-itertools_1592197792446/work
# mpmath==1.1.0
# msgpack==1.0.0
# multipledispatch==0.6.0
# mypy-extensions==0.4.3
# nb-conda==2.2.1
# nb-conda-kernels==2.2.3
# nbclient @ file:///home/conda/feedstock_root/build_artifacts/nbclient_1591814389930/work
# nbconvert==5.6.1
# nbdime @ file:///home/conda/feedstock_root/build_artifacts/nbdime_1588773248389/work
# nbformat @ file:///home/conda/feedstock_root/build_artifacts/nbformat_1594060262917/work
# nbpresent==3.0.2
# nest-asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1588514211290/work
# networkx==2.4
# nltk==3.4.4
# nose==1.3.7
# notebook==5.2.2
# notebook-executor @ file:///opt/conda/conda-bld/dlenv-base_1593468110918/work/packages/notebook_executor
# numba @ file:///home/conda/feedstock_root/build_artifacts/numba_1594008868297/work
# numexpr==2.7.1
# numpy==1.19.0
# numpydoc @ file:///home/conda/feedstock_root/build_artifacts/numpydoc_1593656006205/work
# oauth2client==3.0.0
# oauthlib==3.1.0
# olefile==0.46
# openpyxl @ file:///home/conda/feedstock_root/build_artifacts/openpyxl_1593690790606/work
# opt-einsum==3.2.1
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1589925210001/work
# pandas==0.24.2
# pandas-profiling @ file:///home/conda/feedstock_root/build_artifacts/pandas-profiling_1589366436905/work
# pandocfilters==1.4.2
# papermill @ file:///home/conda/feedstock_root/build_artifacts/papermill_1593559108098/work
# parso==0.5.2
# partd==1.1.0
# path @ file:///home/conda/feedstock_root/build_artifacts/path_1590330789695/work
# path.py==12.0.2
# pathlib2==2.3.5
# pathspec==0.8.0
# pathtools==0.1.2
# patsy==0.5.1
# pbr==5.4.5
# pep8==1.7.1
# pexpect==4.8.0
# phik @ file:///home/conda/feedstock_root/build_artifacts/phik_1590331950347/work
# pickleshare==0.7.5
# Pillow @ file:///home/conda/feedstock_root/build_artifacts/pillow_1593694121332/work
# pkginfo==1.5.0.1
# pluggy @ file:///home/conda/feedstock_root/build_artifacts/pluggy_1592827471208/work
# ply==3.11
# portpicker==1.2.0
# poyo==0.5.0
# prettytable==0.7.2
# prometheus-client @ file:///home/conda/feedstock_root/build_artifacts/prometheus_client_1590412252446/work
# promise==2.3
# prompt-toolkit==1.0.18
# protobuf==3.12.3
# psutil==5.7.0
# ptyprocess==0.6.0
# py @ file:///home/conda/feedstock_root/build_artifacts/py_1593088446458/work
# pyarrow==0.17.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycparser @ file:///home/conda/feedstock_root/build_artifacts/pycparser_1593275161868/work
# pycrypto==2.6.1
# pycurl==7.43.0.5
# pydocstyle==5.0.2
# pydot==1.4.1
# pyflakes==2.1.1
# Pygments==2.6.1
# PyJWT==1.7.1
# pylint @ file:///home/conda/feedstock_root/build_artifacts/pylint_1592404303629/work
# pymongo==3.10.1
# pyodbc==4.0.30
# pyOpenSSL==19.1.0
# pyparsing==2.4.7
# PyQt5==5.12.3
# PyQt5-sip==4.19.18
# PyQtChart==5.12
# PyQtWebEngine==5.12.1
# pyrsistent==0.16.0
# PySocks==1.7.1
# pytest==5.4.3
# pytest-arraydiff==0.3
# pytest-astropy==0.7.0
# pytest-astropy-header==0.1.2
# pytest-doctestplus @ file:///home/conda/feedstock_root/build_artifacts/pytest-doctestplus_1591908454504/work
# pytest-openfiles @ file:///home/conda/feedstock_root/build_artifacts/pytest-openfiles_1591909410901/work
# pytest-remotedata==0.3.1
# python-dateutil==2.8.1
# python-jsonrpc-server @ file:///home/conda/feedstock_root/build_artifacts/python-jsonrpc-server_1588783985962/work
# python-language-server==0.31.10
# python-slugify @ file:///home/conda/feedstock_root/build_artifacts/python-slugify_1593573453419/work
# pytz==2020.1
# PyWavelets==1.1.1
# pyxdg==0.26
# PyYAML==5.3.1
# pyzmq==19.0.1
# QDarkStyle==2.8.1
# QtAwesome @ file:///home/conda/feedstock_root/build_artifacts/qtawesome_1588715536397/work
# qtconsole @ file:///home/conda/feedstock_root/build_artifacts/qtconsole_1592845750760/work
# QtPy==1.9.0
# regex @ file:///home/conda/feedstock_root/build_artifacts/regex_1591646121522/work
# requests==2.21.0
# requests-oauthlib==1.3.0
# retrying==1.3.3
# rope @ file:///home/conda/feedstock_root/build_artifacts/rope_1588950285934/work
# rsa @ file:///home/conda/feedstock_root/build_artifacts/rsa_1591996208734/work
# Rtree==0.9.4
# ruamel-yaml==0.15.80
# scikit-image==0.17.2
# scikit-learn @ file:///home/conda/feedstock_root/build_artifacts/scikit-learn_1589920855303/work
# scipy @ file:///home/conda/feedstock_root/build_artifacts/scipy_1593253469108/work
# seaborn @ file:///home/conda/feedstock_root/build_artifacts/seaborn-base_1591878760859/work
# SecretStorage==3.1.2
# Send2Trash==1.5.0
# simplegeneric==0.8.1
# simplejson @ file:///home/conda/feedstock_root/build_artifacts/simplejson_1588608463837/work
# singledispatch==3.4.0.3
# sip==4.19.23
# six==1.12.0
# smmap @ file:///home/conda/feedstock_root/build_artifacts/smmap_1588651577140/work
# snowballstemmer==2.0.0
# sortedcollections @ file:///home/conda/feedstock_root/build_artifacts/sortedcollections_1591583091437/work
# sortedcontainers @ file:///home/conda/feedstock_root/build_artifacts/sortedcontainers_1591999956871/work
# soupsieve @ file:///home/conda/feedstock_root/build_artifacts/soupsieve_1589778966114/work
# Sphinx @ file:///home/conda/feedstock_root/build_artifacts/sphinx_1593947940626/work
# sphinxcontrib-applehelp==1.0.2
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==1.0.3
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.4
# sphinxcontrib-websupport @ file:///home/conda/feedstock_root/build_artifacts/sphinxcontrib-websupport_1593344032344/work
# spyder @ file:///home/conda/feedstock_root/build_artifacts/spyder_1588993801519/work
# spyder-kernels @ file:///home/conda/feedstock_root/build_artifacts/spyder-kernels_1588785827687/work
# SQLAlchemy @ file:///home/conda/feedstock_root/build_artifacts/sqlalchemy_1593116989295/work
# sqlparse==0.3.1
# statsmodels @ file:///home/conda/feedstock_root/build_artifacts/statsmodels_1591963256838/work
# sympy @ file:///home/conda/feedstock_root/build_artifacts/sympy_1593716797971/work
# tables==3.6.1
# tabulate==0.8.7
# tangled-up-in-unicode @ file:///home/conda/feedstock_root/build_artifacts/tangled-up-in-unicode_1589363771888/work
# tblib==1.6.0
# tenacity @ file:///home/conda/feedstock_root/build_artifacts/tenacity_1588242769366/work
# tensorboard==2.1.1
# tensorflow @ file:///opt/conda/conda-bld/dlenv-tf-2-1-cpu_1594185789553/work/tensorflow-2.1.1-cp37-cp37m-linux_x86_64.whl
# tensorflow-data-validation==0.22.2
# tensorflow-datasets==2.0.0
# tensorflow-enterprise-addons @ file:///opt/conda/conda-bld/dlenv-tf-2-1-cpu_1594185789553/work/tensorflow_enterprise_addons-0.0.0-py3-none-any.whl
# tensorflow-estimator==2.1.0
# tensorflow-hub==0.7.0
# tensorflow-io==0.11.0
# tensorflow-metadata==0.22.2
# tensorflow-model-analysis==0.22.2
# tensorflow-probability==0.9.0
# tensorflow-serving-api==2.1.0
# tensorflow-transform==0.22.0
# termcolor==1.1.0
# terminado==0.8.3
# terminaltables==3.1.0
# testpath==0.4.4
# text-unidecode==1.3
# textwrap3==0.9.2
# tfx==0.22.0
# tfx-bsl==0.22.1
# threadpoolctl @ file:///tmp/tmp79xdzxkt/threadpoolctl-2.1.0-py3-none-any.whl
# tifffile @ file:///home/conda/feedstock_root/build_artifacts/tifffile_1593913740982/work
# toml @ file:///home/conda/feedstock_root/build_artifacts/toml_1589469402899/work
# toolz==0.10.0
# tornado==4.5.3
# tqdm @ file:///home/conda/feedstock_root/build_artifacts/tqdm_1593390011681/work
# traitlets==4.3.3
# typed-ast==1.4.1
# typing-extensions @ file:///home/conda/feedstock_root/build_artifacts/typing_extensions_1588470653596/work
# ujson==1.35
# unicodecsv==0.14.1
# Unidecode==1.1.1
# uritemplate==3.0.1
# urllib3==1.24.3
# visions @ file:///home/conda/feedstock_root/build_artifacts/visions_1589284473785/work
# watchdog @ file:///home/conda/feedstock_root/build_artifacts/watchdog_1593120501703/work
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1592931742287/work
# webencodings==0.5.1
# websocket-client==0.57.0
# Werkzeug==1.0.1
# whichcraft==0.6.1
# widgetsnbextension @ file:///home/conda/feedstock_root/build_artifacts/widgetsnbextension_1594164347302/work
# witwidget==1.7.0
# wrapt==1.12.1
# wurlitzer==2.0.0
# xlrd==1.2.0
# XlsxWriter @ file:///home/conda/feedstock_root/build_artifacts/xlsxwriter_1590799523302/work
# xlwt==1.3.0
# yapf==0.29.0
# zict==2.0.0
# zipp==3.1.0
# zope.event @ file:///home/conda/feedstock_root/build_artifacts/zope.event_1591372894284/work
# zope.interface==5.1.0
